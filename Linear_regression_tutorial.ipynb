# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt
from random import gauss

# %%
# generating simulated data
alpha = 2
beta = 0.5
sigma = 1 # noise term variance
N = 15 # number of samples

## simulate data
x = np.array( [ gauss(0,1) for i in range(N)])
noise = np.array( [ gauss(0,sigma) for i in range(N)])
y = np.multiply( alpha, x) + beta + noise

# %% [markdown]
# ## 1. Get to know the data and variables defined above

# %% [markdown]
# ## 2. Fit the linear regression model

# %%
# fit the linear regression model

# Append ones to the x along the appropriate axis so as to allow for a bias term

# Perform linear regresssion by computing the parameters A, b and weight vector w

# %% [markdown]
# ## 3. Plot the data and the linear regression line

# %%
# plot data

# plot the true line (from parameters alpha and beta)

# plot the line fitted by linear regression (from linear regression parameters)

# %% [markdown]
# ## 4. How much do the results of linear regression depend on the given training set?

# %%
# generating simulated data
alpha = 2
beta = 0.5
sigma = 1 # noise term variance
N = 10

# Write a loop to create several training datasets with N=10 samples with the
# given parameters and perform linear regression on each of the training 
# sets. Save the weight vectors that result from each iteration. You can run
# the loop for 1000 iterations

# %% [markdown]
# ## 5. Plot the histogram of each component of the weight vector
